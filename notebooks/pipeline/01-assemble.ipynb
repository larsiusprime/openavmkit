# %% [markdown]
# # Assemble
#
# This notebook loads and assembles all your basic data sources, including tabulor and geospatial data.
#
# The final output is two dataframes:
#
# - UNIVERSE
# - SALES
#
# The SALES dataframe represents transactions or parcels; these are ownership transfers with prices, dates, and metadata.
# The UNIVERSE dataframe represents the parcels themselves (land and buildings, and their associated characteristics).
#
# These will be packaged together in a handy data structure called a `SalesUniversePair`, or `sup` for short. `openavmkit` provides many handy functions that carefully perform operations on `sup`s without mixing up their fields.
#
# The key thing to understand is that the **Assemble** notebook outputs a `sup` that represents *factual assertions* about the world. In later notebooks, we will have to add assumptions, opinions, and educated guesses, but we first will establish the firmest facts we can in this notebook.
#
# You can think of the two dataframes in the `sup` as answering the following questions:
#
# - UNIVERSE:
#   - Where is each parcel located in space, and what is its shape?
#   - What are the *current* characteristics of each parcel?
#     - Which parcels have buildings and which are vacant lots?
#     - How big is each parcel?
#     - What is the age/size/quality/condition/etc of each building?
# - SALES:
#   - Which parcels have sold?
#   - What prices did they sell for?
#   - What dates did they sell on?
#   - Which sales were valid?
#   - What characteristics were different *at the time of sale* from how the parcel is now?

# %%
# Change these as desired

# The slug of the locality you are currently working on
locality = "us-md-baltimorecity"

# Whether to print out a lot of stuff (can help with debugging) or stay mostly quiet
verbose = True

# Clear previous state for this notebook and start fresh
clear_checkpoints = True

# %% [markdown]
# # 1. Basic setup

# %%
import init_notebooks
init_notebooks.setup_environment()
# Out:
# Environment setup completed.

# %%
# import OpenAVMkit:
from openavmkit.pipeline import ( 
    init_notebook,
    from_checkpoint,
    delete_checkpoints,
    examine_df,
    examine_df_in_ridiculous_detail,
    examine_sup,
    examine_sup_in_ridiculous_detail,
    cloud_sync,
    load_settings,
    load_dataframes,
    process_data,
    process_sales,
    tag_model_groups_sup,
    write_notebook_output_sup
)

# %%
init_notebook(locality)
# Out:
# locality = us-md-baltimorecity
# base path = /Users/gregmiller/Documents/openavmkit/openavmkit/notebooks/pipeline
# current path = /Users/gregmiller/Documents/openavmkit/openavmkit/notebooks/pipeline/data/us-md-baltimorecity

# %%
if clear_checkpoints:
    delete_checkpoints("1-assemble")

# %%
settings = load_settings()

# %% [markdown]
# # 2. Sync with Cloud
# - If you have configured cloud storage, syncs with your remote storage
# - Reconciles your local input files with the versions on the remote server
# - Pulls down whatever is newer from the remote server
# - Uploads whatever is newer from your local machine

# %%
ignore_paths = [
    "in/aw/bright",
    "us/md/baltimorecity/raw/bright",
    "us/md/baltimorecity/aw",
    "us/md/baltimorecity/w/",
    "us/md/baltimorecity/aw/bright",  # Ignore the entire bright folder
    "us/md/baltimorecity/aw/bright/bd_20250303_173558.4.csv"  # Ignore a specific file
]
cloud_sync(locality, verbose=True, env_path="../../../.env", settings=settings, ignore_paths=ignore_paths)

# %% [markdown]
# # 3. Load & process data

# %%
# load all of our initial dataframes, but don't do anything with them just yet
dataframes = from_checkpoint("1-assemble-01-load_dataframes", load_dataframes,
    {
        "settings":settings,
        "verbose":verbose
    }
)
# Out:
# Loading "in/geo/regrid_parcels.parquet"...
# Loading "in/Real_Property_Information.parquet"...
# Loading "in/bright_combined_reduced.parquet"...
# Loading "in/sales.parquet"...
# Valid sales: 101546 out of 241196 total
# Loading "in/sales.parquet"...
# Valid sales: 58477 out of 241196 total
# Loading "in/sales.parquet"...
# Valid sales: 39235 out of 241196 total
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # load all of our initial dataframes, but don't do anything with them just yet
# ----> 2 dataframes = from_checkpoint("1-assemble-01-load_dataframes", load_dataframes,
#       3     {
#       4         "settings":settings,
#       5         "verbose":verbose
#       6     }
#       7 )
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/pipeline.py:663, in from_checkpoint(path, func, params)
#     649 def from_checkpoint(path: str, func: callable, params: dict) -> pd.DataFrame:
#     650    """
#     651    Wrapper function -- read cached data from a checkpoint file if it exists, otherwise run the specified function to
#     652    generate the data (and save it to a checkpoint file).
#    (...)
#     661    :rtype: pd.DataFrame
#     662    """
# --> 663    return openavmkit.checkpoint.from_checkpoint(path, func, params)
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/checkpoint.py:16, in from_checkpoint(path, func, params)
#      14   return read_checkpoint(path)
#      15 else:
# ---> 16   result = func(**params)
#      17   write_checkpoint(result, path)
#      18   return result
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/pipeline.py:477, in load_dataframes(settings, verbose)
#     475 for key in s_load:
#     476    entry = s_load[key]
# --> 477    df = _load_dataframe(entry, settings, verbose=verbose,
#     478       fields_cat=fields_cat, fields_bool=fields_bool, fields_num=fields_num)
#     479    if df is not None:
#     480       dataframes[key] = df
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/data.py:2189, in _load_dataframe(entry, settings, verbose, fields_cat, fields_bool, fields_num)
#    2186 filename = f"in/{filename}"
#    2187 ext = str(filename).split(".")[-1]
# -> 2189 column_names = _snoop_column_names(filename)
#    2191 e_load = entry.get("load", {})
#    2193 # Get all calc and tweak operations in order they appear
#
# File ~/Documents/openavmkit/openavmkit/openavmkit/data.py:2343, in _snoop_column_names(filename)
#    2341   return parquet_file.schema.names
#    2342 elif ext == "csv":
# -> 2343   return pd.read_csv(filename, nrows=0).columns.tolist()
#    2344 raise ValueError(f"Unsupported file extension: \"{ext}\"")
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'in/likely_garage.csv'

# %%
# assemble our data
sales_univ_pair = from_checkpoint("1-assemble-02-process_data", process_data,
    {
        "dataframes":dataframes, 
        "settings":settings, 
        "verbose":verbose
    }
)
# Out:
# Dropped 2375661 duplicate rows based on '['key']'
# Valid sales: 199248 (27.5% of 723528 total)
# Enriching universe...
# Performing basic geometric enrichment...
# --> added latitude/longitude...(1.51s)
# --> calculated GIS area of each parcel...(0.03s)
# HO
# YO
# --> calculated parcel rectangularity...(27.59s)
# --> calculated parcel aspect ratios...(0.73s)
# --> identifying irregular parcels...
# ----> simplified geometry...(1.89s)
# ----> identified triangular parcels...(25.62s)
# ----> identified complex geometry...(1.83s)
# ----> identified elongated parcels...(0.00s)
# ----> finished up...(0.70s)
# --> identified irregular parcels (total)...(30.04s)
# --> calculated polar coordinates...(9.90s)
# Performing spatial joins...
# Enriching with Overture building data...
# --> Current settings: {'enabled': True, 'cache': True, 'footprint': {'units': 'sqft'}}
# --> Bounding box: [-76.711309   39.1972805 -76.5296665  39.372015 ]
# --> Fetching data from Overture...
# --> Counting batches...
# --> Found 243 batches
# Processing batches: 100%|██████████| 243/243 [00:14<00:00, 17.01it/s]
# --> Found 280484 buildings
# --> Available columns: ['id', 'geometry', 'bbox', 'theme', 'type', 'version', 'sources', 'level', 'subtype', 'class', 'height', 'names', 'has_parts', 'is_underground', 'num_floors', 'num_floors_underground', 'min_height', 'min_floor', 'facade_color', 'facade_material', 'roof_material', 'roof_shape', 'roof_direction', 'roof_orientation', 'roof_color', 'roof_height']
# --> Calculating building footprint areas...
# --> Using UTM CRS: EPSG:32618
# --> Saving buildings to cache: cache/overture/buildings_-76.711309_39.1972805_-76.5296665_39.372015.parquet
# --> Projected to equal area CRS...(1.02s)
# --> Calculated building footprint intersections with parcels...(3.68s)
# --> Found 1575916 potential building-parcel intersections
# --> Calculated precise intersection areas...(69.54s)
# --> Aggregated building footprint areas...(0.13s)
# --> Finished up...(0.23s)
# --> Added building footprint areas to 236505 parcels
# --> Total building footprint area: 1,544,685,360 sqft
# --> Average building footprint area: 6,531 sqft
# --> Number of parcels with buildings: 219,360
# --> Saving intersection areas to cache: cache/overture/intersections_-76.711309_39.1972805_-76.5296665_39.372015.parquet
# Performing distance calculations...
# --> Skipping water_bodies - not found in dataframes (likely disabled in settings)
# --> Skipping water_bodies_top - not found in dataframes (likely disabled in settings)
# --> Skipping parks - not found in dataframes (likely disabled in settings)
# --> Skipping parks_top - not found in dataframes (likely disabled in settings)
# --> Skipping golf_courses - not found in dataframes (likely disabled in settings)
# --> Skipping golf_courses_top - not found in dataframes (likely disabled in settings)
# --> Skipping educational - not found in dataframes (likely disabled in settings)
# --> Skipping educational_top - not found in dataframes (likely disabled in settings)
# --> Skipping transportation - not found in dataframes (likely disabled in settings)
# --> Skipping transportation_top - not found in dataframes (likely disabled in settings)
# Using "key" to merge shapefiles onto df
#
# === Starting inference for field 'bldg_area_finished_sqft' ===
#
# Initial masks:
# --> Total rows: 236505
# --> Inference mask True: 50348
# --> Training mask True: 186135
#
# Data split:
# --> Full training samples: 186,135
# --> Training samples: 167,521
# --> Validation samples: 18,614
#
# === Running Model Experiments ===
#
# Trying random_forest model:
#
# Fitting Random Forest model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.3474
# --> assr_impr_value: 0.2067
# --> bldg_style: 0.1403
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1163
# --> census_block_group: 0.0578
# --> block: 0.0561
# --> zoning_type: 0.0454
# --> neighborhood: 0.0301
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1163
#
# Regular Validation Results:
#
# Training performance:
# --> mae: 135.6677
# --> rmse: 523.6180
# --> r2: 0.9361
# --> mape: 26.9263
#
# Validation performance:
# --> mae: 220.6604
# --> rmse: 796.4698
# --> r2: 0.8283
# --> mape: 62.6033
#
# Trying lightgbm model:
#
# Fitting LightGBM model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000916 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1591
# [LightGBM] [Info] Number of data points in the train set: 167521, number of used features: 8
# [LightGBM] [Info] Start training from score 1576.779371
#
# Feature importances:
# --> bldg_area_footprint_sqft: 1472.0000
# --> bldg_style: 1059.0000
# --> assr_impr_value: 776.0000
# --> census_block_group: 735.0000
# --> block: 722.0000
# --> zoning_type_x_bldg_style_x_census_block_group: 596.0000
# --> neighborhood: 419.0000
# --> zoning_type: 221.0000
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 596.0000
#
# Regular Validation Results:
#
# Training performance:
# --> mae: 261.2486
# --> rmse: 748.2654
# --> r2: 0.8696
# --> mape: 47.0075
#
# Validation performance:
# --> mae: 277.5716
# --> rmse: 824.3300
# --> r2: 0.8161
# --> mape: 80.3964
#
# Trying xgboost model:
#
# Fitting XGBoost model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.2375
# --> bldg_style: 0.1693
# --> zoning_type: 0.1680
# --> assr_impr_value: 0.1666
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1033
# --> census_block_group: 0.0682
# --> block: 0.0607
# --> neighborhood: 0.0262
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1033
#
# Regular Validation Results:
#
# Training performance:
# --> mae: 256.5684
# --> rmse: 712.1556
# --> r2: 0.8819
# --> mape: 35.8201
#
# Validation performance:
# --> mae: 283.0482
# --> rmse: 849.5738
# --> r2: 0.8046
# --> mape: 69.9730
#
# Trying ensemble model:
#
# Fitting LightGBM model...
#
# Fitting LightGBM model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000662 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1586
# [LightGBM] [Info] Number of data points in the train set: 134016, number of used features: 8
# [LightGBM] [Info] Start training from score 1576.437687
#
# Feature importances:
# --> bldg_area_footprint_sqft: 1470.0000
# --> bldg_style: 1101.0000
# --> assr_impr_value: 769.0000
# --> census_block_group: 724.0000
# --> block: 701.0000
# --> zoning_type_x_bldg_style_x_census_block_group: 601.0000
# --> neighborhood: 446.0000
# --> zoning_type: 188.0000
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 601.0000
#
# Fitting XGBoost model...
#
# Fitting XGBoost model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.2396
# --> bldg_style: 0.1792
# --> assr_impr_value: 0.1729
# --> zoning_type: 0.1395
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1018
# --> census_block_group: 0.0693
# --> block: 0.0681
# --> neighborhood: 0.0296
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1018
#
# Fitting Random Forest model...
#
# Fitting Random Forest model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.3435
# --> assr_impr_value: 0.2031
# --> bldg_style: 0.1500
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1171
# --> block: 0.0582
# --> census_block_group: 0.0551
# --> zoning_type: 0.0436
# --> neighborhood: 0.0294
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1171
#
# Ensemble weights:
# --> LightGBM: 0.0531
# --> XGBoost: 0.3279
# --> Random Forest: 0.6190
#
# Fitting LightGBM model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000780 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1591
# [LightGBM] [Info] Number of data points in the train set: 167521, number of used features: 8
# [LightGBM] [Info] Start training from score 1576.779371
#
# Feature importances:
# --> bldg_area_footprint_sqft: 1472.0000
# --> bldg_style: 1059.0000
# --> assr_impr_value: 776.0000
# --> census_block_group: 735.0000
# --> block: 722.0000
# --> zoning_type_x_bldg_style_x_census_block_group: 596.0000
# --> neighborhood: 419.0000
# --> zoning_type: 221.0000
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 596.0000
#
# Fitting XGBoost model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.2375
# --> bldg_style: 0.1693
# --> zoning_type: 0.1680
# --> assr_impr_value: 0.1666
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1033
# --> census_block_group: 0.0682
# --> block: 0.0607
# --> neighborhood: 0.0262
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1033
#
# Fitting Random Forest model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.3474
# --> assr_impr_value: 0.2067
# --> bldg_style: 0.1403
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1163
# --> census_block_group: 0.0578
# --> block: 0.0561
# --> zoning_type: 0.0454
# --> neighborhood: 0.0301
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1163
#
# Regular Validation Results:
#
# Training performance:
# --> mae: 175.6858
# --> rmse: 577.8102
# --> r2: 0.9222
# --> mape: 30.5137
#
# Validation performance:
# --> mae: 236.4639
# --> rmse: 793.0583
# --> r2: 0.8298
# --> mape: 65.5098
#
# Best performing model: ensemble (R² = 0.8298)
# Currently using: ensemble
#
# Regular Validation Results:
#
# Training Metrics:
#       random_forest  lightgbm   xgboost  ensemble
# mae        135.6677  261.2486  256.5684  175.6858
# rmse       523.6180  748.2654  712.1556  577.8102
# r2           0.9361    0.8696    0.8819    0.9222
# mape        26.9263   47.0075   35.8201   30.5137
#
# Validation Metrics:
#       random_forest  lightgbm   xgboost  ensemble
# mae        220.6604  277.5716  283.0482  236.4639
# rmse       796.4698  824.3300  849.5738  793.0583
# r2           0.8283    0.8161    0.8046    0.8298
# mape        62.6033   80.3964   69.9730   65.5098
#
# Fitting final model on full training data...
#
# Fitting LightGBM model...
#
# Fitting LightGBM model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000723 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1590
# [LightGBM] [Info] Number of data points in the train set: 148908, number of used features: 8
# [LightGBM] [Info] Start training from score 1576.360672
#
# Feature importances:
# --> bldg_area_footprint_sqft: 1437.0000
# --> bldg_style: 1053.0000
# --> census_block_group: 777.0000
# --> assr_impr_value: 755.0000
# --> block: 717.0000
# --> zoning_type_x_bldg_style_x_census_block_group: 644.0000
# --> neighborhood: 416.0000
# --> zoning_type: 201.0000
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 644.0000
#
# Fitting XGBoost model...
#
# Fitting XGBoost model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.2332
# --> assr_impr_value: 0.1695
# --> bldg_style: 0.1665
# --> zoning_type: 0.1528
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1146
# --> census_block_group: 0.0672
# --> block: 0.0663
# --> neighborhood: 0.0298
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1146
#
# Fitting Random Forest model...
#
# Fitting Random Forest model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.3475
# --> assr_impr_value: 0.1994
# --> bldg_style: 0.1363
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1234
# --> block: 0.0605
# --> census_block_group: 0.0568
# --> zoning_type: 0.0460
# --> neighborhood: 0.0301
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1234
#
# Ensemble weights:
# --> LightGBM: 0.3240
# --> XGBoost: 0.3245
# --> Random Forest: 0.3515
#
# Fitting LightGBM model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000895 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1592
# [LightGBM] [Info] Number of data points in the train set: 186135, number of used features: 8
# [LightGBM] [Info] Start training from score 1573.248631
#
# Feature importances:
# --> bldg_area_footprint_sqft: 1509.0000
# --> bldg_style: 1113.0000
# --> census_block_group: 749.0000
# --> assr_impr_value: 728.0000
# --> block: 659.0000
# --> zoning_type_x_bldg_style_x_census_block_group: 580.0000
# --> neighborhood: 449.0000
# --> zoning_type: 213.0000
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 580.0000
#
# Fitting XGBoost model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.2396
# --> bldg_style: 0.1730
# --> assr_impr_value: 0.1678
# --> zoning_type: 0.1577
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1116
# --> block: 0.0657
# --> census_block_group: 0.0591
# --> neighborhood: 0.0255
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1116
#
# Fitting Random Forest model:
# Features being used: ['assr_impr_value', 'bldg_area_footprint_sqft', 'neighborhood', 'census_block_group', 'zoning_type', 'block', 'bldg_style', 'zoning_type_x_bldg_style_x_census_block_group']
# Interaction features: ['zoning_type_x_bldg_style_x_census_block_group']
#
# Feature importances:
# --> bldg_area_footprint_sqft: 0.3442
# --> assr_impr_value: 0.2099
# --> bldg_style: 0.1394
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1187
# --> block: 0.0586
# --> census_block_group: 0.0553
# --> zoning_type: 0.0437
# --> neighborhood: 0.0302
#
# Interaction feature importances:
# --> zoning_type_x_bldg_style_x_census_block_group: 0.1187
# Enriching with Census data...
# Enriching with OpenStreetMap data...
# Enriching with OpenStreetMap data...
# --> Getting water bodies...
# --> Found 47 water bodies
# --> Getting transportation networks...
# --> Found 222 transportation networks
# --> Getting educational institutions...
# Found 22 raw educational features
# After dissolving by name: 22 unique institutions
# --> Found 18 educational institutions
# --> Getting parks...
# --> Found 347 parks
# --> Getting golf courses...
# --> Found 5 golf courses
# Performing reference table joins...
# Enriching sales...
# Dropped 1427 duplicate rows based on '['key_sale']'

# %%
# process the sales
sales_univ_pair = from_checkpoint("1-assemble-03-process_sales", process_sales,
    {
        "sup": sales_univ_pair, 
        "settings": settings, 
        "verbose": verbose
    }
)
# Out:
# Before univ merge len = 197821
# After univ merge len = 197821
# Using 53837 sales...
# --> 512 vacant sales
# --> 53325 improved sales
# --> 53205 valid for ratio study
# --> 512 valid for land ratio study
# len before hydrate = 53837
# len after hydrate = 53837
# Applying time adjustment...
# Calculating time adjustment...
# /Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/gregmiller/Documents/openavmkit/openavmkit/.venv/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# --> Using period: Q
# --> Crunching time adjustment...
# --> Flattening time adjustment...
# ---->interpolating missing periods...
# --> Time adjustment calculated for 5183 days.
# len after enrich = 53837
# Number of parcels in universe with coordinates: 236505 / 236505
# Number of parcels in universe with coordinates: 236505 / 236505
# Number of parcels in universe with coordinates: 236505 / 236505
# Number of parcels in universe with coordinates: 236505 / 236505

# %% [markdown]
# # 4. Inspect results
#
# ## 4.1 Examine
#
# - Run the next cell and look at the printed out results.
# - Note the "Non-zero" and "Non-null" columns in particular and make sure they're what you expect
# - This view is for a quick glance to get a good idea of what all your data is

# %%
settings = load_settings()
#examine_sup(sales_univ_pair, settings)
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                 Float64      219,315   93%    236,505  100%
# exempt_land_value               Float64       16,452    7%    236,471  100%
# geom_aspect_ratio               float64      236,505  100%    236,505  100%
# geom_rectangularity_num         Float64      236,487  100%    236,505  100%
# geom_vertices                    int64       236,492  100%    236,505  100%
# housing_growth_past_5_years     Float64      232,806   98%    236,328  100%
# land_area_gis_delta_percent     Float64      141,996   60%    235,609  100%
# land_area_gis_delta_sqft        Float64      142,892   60%    236,505  100%
# land_area_gis_sqft              float64      236,505  100%    236,505  100%
# land_area_given_sqft            Float64      141,996   60%    142,892   60%
# land_area_sqft                  Float64      235,609  100%    236,505  100%
# latitude                        float64      236,505  100%    236,505  100%
# latitude_norm                   float64      236,504  100%    236,505  100%
# longitude                       float64      236,505  100%    236,505  100%
# longitude_norm                  float64      236,504  100%    236,505  100%
# median_household_income         Float64      235,479  100%    236,328  100%
# polar_angle                     float64      236,505  100%    236,505  100%
# polar_radius                    float64      236,505  100%    236,505  100%
# population_density              Float64      236,328  100%    236,328  100%
# population_gr...h_past_5_years  Float64      235,371  100%    236,328  100%
# spatial_lag_s...price_time_adj  float64      236,505  100%    236,505  100%
# spatial_lag_s..._adj_impr_sqft  float64      236,505  100%    236,505  100%
# spatial_lag_s..._adj_land_sqft  float64      236,505  100%    236,505  100%
# spatial_lag_s...ime_adj_vacant  float64      236,505  100%    236,505  100%
# transmission_line_distance      Float64      233,812   99%    234,959   99%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_geom_complex                   bool         3,636    2%    236,505  100%                            [False, True]
# is_geom_elongated                 bool        97,242   41%    236,505  100%                            [False, True]
# is_geom_irregular                 bool       102,078   43%    236,505  100%                            [False, True]
# is_geom_triangular                bool         2,044    1%    236,505  100%                            [False, True]
# is_vacant                         bool        17,145    7%    236,505  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# block                            string      236,505  100%    236,505  100%                                    5,547
# census_block                     string      236,505  100%    236,505  100%                                    9,163
# census_block_group               string      236,505  100%    236,505  100%                                      642
# census_tract                     string      236,505  100%    236,505  100%                                      218
# city                             string      236,505  100%    236,505  100%                            ['baltimore']
# lbcs_site_desc                   string      220,510   93%    220,510   93%                                        4
# lot                              string      236,471  100%    236,471  100%                                    3,080
# neighborhood                     string      235,850  100%    235,850  100%                                      281
# parcel_use_code                  string      236,471  100%    236,471  100%                                       12
# parcel_use_desc                  string      157,418   67%    157,418   67%                                       12
# police_district                  string      235,816  100%    235,816  100%                                       10
# risk_disaster                    string      236,318  100%    236,318  100%                                        5
# risk_flood                       string      234,215   99%    234,215   99%                                        4
# section                          string      236,471  100%    236,471  100%                                       67
# ward                             string      236,505  100%    236,505  100%                                       29
# zip                              string      236,505  100%    236,505  100%                                       41
# zoning                           string      236,504  100%    236,504  100%                                       71
# zoning_desc                      string      236,502  100%    236,502  100%                                       45
# zoning_subtype                   string      236,502  100%    236,502  100%                                       14
# zoning_type                      string      236,502  100%    236,502  100%                                        7
# zoning_url                       string      236,502  100%    236,502  100%                                        4
#
# ============================== ========== ========== ===== ========== ===== ========================================
#          IMPROVEMENT
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_bldg_area_finished_sqft    Float64      169,012   71%    234,908   99%
# assr_impr_value                 Float64      206,953   88%    236,505  100%
# bldg_age_years                  Float64      178,597   76%    236,505  100%
# bldg_area_finished_sqft         Float64      219,360   93%    236,505  100%
# bldg_area_fin...ed_sqft_zillow  Float64      130,236   55%    150,072   63%
# bldg_area_footprint_sqft        float64      219,360   93%    236,505  100%
# bldg_count                      Float64      214,122   91%    236,505  100%
# bldg_quality_num                Float64      106,631   45%    123,776   52%
# bldg_rooms_bath                 Float64      134,728   57%    153,275   65%
# bldg_rooms_bed                  Float64       81,230   34%     99,323   42%
# bldg_stories                    Float64        8,724    4%     25,869   11%
# bldg_units                      Float64          261    0%    236,505  100%
# bldg_year_built                 Float64      178,597   76%    195,742   83%
# exempt_impr_value               Float64        7,170    3%    236,490  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# inferred_bldg..._finished_sqft    bool        50,348   21%    236,505  100%                            [False, True]
# is_bldg_vacant                   object      219,345   93%    236,490  100%                       [True, False, nan]
# is_usps_vacant                    bool       219,360   93%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# bldg_class                       string      168,114   71%    168,114   71%                                       11
# bldg_construction                string      118,762   50%    118,762   50%                                       22
# bldg_desc                        string      154,164   65%    154,164   65%                                      109
# bldg_quality_txt                 string      236,505  100%    236,505  100%                                       11
# bldg_style                       string      124,775   53%    124,775   53%                                      134
# lbcs_activity_desc               string      228,637   97%    228,637   97%                                        7
# lbcs_function_desc               string      228,637   97%    228,637   97%                                        7
# lbcs_structure_desc              string      228,542   97%    228,542   97%                                        6
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_market_value               Float64      219,397   93%    236,505  100%
# credit_city_homestead           Float64          221    0%    233,674   99%
# credit_state_homestead          Float64        5,355    2%    236,471  100%
# sale_age_days                    Int64       236,502  100%    236,502  100%
# sale_month                      float64      236,502  100%    236,502  100%
# sale_price                      Float64      168,569   71%    236,505  100%
# sale_quarter                    float64      236,502  100%    236,502  100%
# sale_year                       float64      236,502  100%    236,502  100%
# zestimate                       Float64      125,240   53%    125,240   53%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_vacant                         bool        17,145    7%    236,505  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assess_grp                       string      236,471  100%    236,471  100%                    ['2', <NA>, '3', '1']
# assessor                         string      236,384  100%    236,384  100%                                       46
# exempt_code                      string      236,470  100%    236,470  100%                                       81
# exempt_type                      string           32    0%         32    0%                              [<NA>, 'E']
# key                              string      236,505  100%    236,505  100%                                  236,505
# lbcs_ownership_desc              string      199,628   84%    199,628   84%                                       10
# mail_city                        string      170,271   72%    170,271   72%                                    2,980
# mail_state                       string      170,414   72%    170,414   72%                                       87
# mail_zip                         string      221,077   93%    221,077   93%                                   22,951
# owner_vs_renter                  string      236,505  100%    236,505  100%                          ['N', 'H', 'D']
# ownership_mode                   string      207,412   88%    207,412   88%                    ['F', <NA>, 'L', '3']
# parcel_value_type                string      236,505  100%    236,505  100%                               ['MARKET']
# sale_date                      datetime64[ns]    236,502  100%    236,502  100%                                   15,443
# sale_year_month                  object      236,505  100%    236,505  100%                                    1,258
# sale_year_quarter                object      236,505  100%    236,505  100%                                      507
# status_owner                     string      236,471  100%    236,471  100%                    ['N', 'H', <NA>, 'D']
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# address                          object      229,593   97%    229,593   97%                                  226,825
# address_mail                     object      236,471  100%    236,471  100%                                  175,679
# geometry                        geometry     236,505  100%    236,505  100%                                  222,588
# key2                             object      155,045   66%    155,045   66%                                  154,875
#
# EXAMINING SALES...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# spatial_lag_s...price_time_adj  float64       53,711  100%     53,711  100%
# spatial_lag_s..._adj_impr_sqft  float64       53,711  100%     53,711  100%
# spatial_lag_s..._adj_land_sqft  float64       53,711  100%     53,711  100%
# spatial_lag_s...ime_adj_vacant  float64       53,711  100%     53,711  100%
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# sale_age_days                    Int64        53,832  100%     53,832  100%
# sale_month                      float64       53,832  100%     53,832  100%
# sale_price                      Float64       53,837  100%     53,837  100%
# sale_price_time_adj             Float64       53,837  100%     53,837  100%
# sale_quarter                    float64       53,832  100%     53,832  100%
# sale_year                       float64       53,832  100%     53,832  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# vacant_sale                      object          512    1%     53,837  100%                            [False, True]
# valid_for_land_ratio_study        bool           512    1%     53,837  100%                            [False, True]
# valid_for_ratio_study             bool        53,205   99%     53,837  100%                            [True, False]
# valid_sale                       object       53,837  100%     53,837  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string       53,837  100%     53,837  100%                                   47,865
# key_sale                         string       53,837  100%     53,837  100%                                   53,837
# sale_date                      datetime64[ns]     53,832  100%     53,832  100%                                    1,326
# sale_year_month                  object       53,837  100%     53,837  100%                                       64
# sale_year_quarter                object       53,837  100%     53,837  100%                                       23
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# convey_type                      object       53,837  100%     53,837  100%                                        2
# sale_grantor                     object       53,835  100%     53,835  100%                                   43,893
# sale_record                     float64       53,837  100%     53,837  100%                          [1.0, 2.0, 3.0]

# %% [markdown]
# ## 4.2 Examine in ridiculous detail
#
# - You've looked, now LOOK AGAIN. This cell will run `describe()` for each numeric field and `value_counts()` for each categorical field.
# - Use this info to decide which variables are useful/useless
# - Consult this readout when you build your modeling group filters

# %%
#examine_sup_in_ridiculous_detail(sales_univ_pair, settings)
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                 Float64      219,315   93%    236,505  100%
# DESCRIBE --> count        236505.0
# mean     52546.581189
# std      348412.83972
# min               0.0
# 25%           10000.0
# 50%           30000.0
# 75%           57000.0
# max       123000000.0
# Name: assr_land_value, dtype: Float64
#
#
# exempt_land_value               Float64       16,452    7%    236,471  100%
# DESCRIBE --> count         236471.0
# mean      13426.239801
# std      484200.549976
# min                0.0
# 25%                0.0
# 50%                0.0
# 75%                0.0
# max        114383100.0
# Name: exempt_land_value, dtype: Float64
#
#
# geom_aspect_ratio               float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean          4.658626
# std           3.332158
# min           1.000000
# 25%           2.720550
# 50%           4.383906
# 75%           6.319230
# max         520.337178
# Name: geom_aspect_ratio, dtype: float64
#
#
# geom_rectangularity_num         Float64      236,487  100%    236,505  100%
# DESCRIBE --> count      236505.0
# mean       0.887988
# std         0.57851
# min     -197.012528
# 25%        0.914734
# 50%        0.961663
# 75%         0.98819
# max             1.0
# Name: geom_rectangularity_num, dtype: Float64
#
#
# geom_vertices                    int64       236,492  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean          5.292193
# std           1.821673
# min           0.000000
# 25%           5.000000
# 50%           5.000000
# 75%           5.000000
# max         373.000000
# Name: geom_vertices, dtype: float64
#
#
# housing_growth_past_5_years     Float64      232,806   98%    236,328  100%
# DESCRIBE --> count    236328.0
# mean     0.127909
# std      7.970822
# min         -1.26
# 25%         -0.82
# 50%          -0.8
# 75%           0.0
# max        188.09
# Name: housing_growth_past_5_years, dtype: Float64
#
#
# land_area_gis_delta_percent     Float64      141,996   60%    235,609  100%
# DESCRIBE --> count       235609.0
# mean       -0.389424
# std        16.411906
# min             -1.0
# 25%        -0.907631
# 50%        -0.903036
# 75%              0.0
# max      4557.591166
# Name: land_area_gis_delta_percent, dtype: Float64
#
#
# land_area_gis_delta_sqft        Float64      142,892   60%    236,505  100%
# DESCRIBE --> count            236505.0
# mean         -67655.95696
# std        3758168.415721
# min     -740013156.453051
# 25%          -1841.025286
# 50%            -904.01245
# 75%                   0.0
# max         492609.083341
# Name: land_area_gis_delta_sqft, dtype: Float64
#
#
# land_area_gis_sqft              float64      236,505  100%    236,505  100%
# DESCRIBE --> count    2.365050e+05
# mean     3.107156e+03
# std      2.621317e+04
# min      1.172472e+00
# 25%      1.058422e+02
# 50%      1.705097e+02
# 75%      4.713004e+02
# max      2.488845e+06
# Name: land_area_gis_sqft, dtype: float64
#
#
# land_area_given_sqft            Float64      141,996   60%    142,892   60%
# DESCRIBE --> count          142892.0
# mean      112301.246431
# std      4834451.953997
# min                 0.0
# 25%              1138.0
# 50%              1742.0
# 75%              3808.0
# max         740014720.0
# Name: land_area_given_sqft, dtype: Float64
#
#
# land_area_sqft                  Float64      235,609  100%    236,505  100%
# DESCRIBE --> count          236505.0
# mean       70763.112698
# std      3758212.172508
# min                 0.0
# 25%          322.819252
# 50%              1294.0
# 75%              2772.0
# max         740014720.0
# Name: land_area_sqft, dtype: Float64
#
#
# latitude                        float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean         39.311793
# std           0.031106
# min          39.199774
# 25%          39.288491
# 50%          39.308744
# 75%          39.336683
# max          39.371993
# Name: latitude, dtype: float64
#
#
# latitude_norm                   float64      236,504  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean          0.650447
# std           0.180618
# min           0.000000
# 25%           0.515139
# 50%           0.632742
# 75%           0.794973
# max           1.000000
# Name: latitude_norm, dtype: float64
#
#
# longitude                       float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean        -76.617806
# std           0.044670
# min         -76.711292
# 25%         -76.652006
# 50%         -76.612957
# 75%         -76.583910
# max         -76.529709
# Name: longitude, dtype: float64
#
#
# longitude_norm                  float64      236,504  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean          0.514837
# std           0.246004
# min           0.000000
# 25%           0.326495
# 50%           0.541542
# 75%           0.701507
# max           1.000000
# Name: longitude_norm, dtype: float64
#
#
# median_household_income         Float64      235,479  100%    236,328  100%
# DESCRIBE --> count        236328.0
# mean     66953.796833
# std      41407.921128
# min               0.0
# 25%           39662.0
# 50%           55890.0
# 75%           81505.0
# max          200001.0
# Name: median_household_income, dtype: Float64
#
#
# polar_angle                     float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean         -1.894362
# std         105.727559
# min        -179.999838
# 25%         -87.693003
# 50%          -1.241054
# 75%          80.334037
# max         179.999972
# Name: polar_angle, dtype: float64
#
#
# polar_radius                    float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean       4711.382020
# std        2160.640475
# min          10.497528
# 25%        3087.772293
# 50%        4466.080224
# 75%        6313.679516
# max       13421.603377
# Name: polar_radius, dtype: float64
#
#
# population_density              Float64      236,328  100%    236,328  100%
# DESCRIBE --> count        236328.0
# mean     12403.587696
# std       8272.541343
# min               5.1
# 25%            6778.2
# 50%           10552.6
# 75%           16052.6
# max           89511.1
# Name: population_density, dtype: Float64
#
#
# population_gr...h_past_5_years  Float64      235,371  100%    236,328  100%
# DESCRIBE --> count    236328.0
# mean    -0.777648
# std       5.92168
# min         -17.9
# 25%         -1.48
# 50%         -1.16
# 75%         -0.33
# max        127.66
# Name: population_growth_past_5_years, dtype: Float64
#
#
# spatial_lag_s...price_time_adj  float64      236,505  100%    236,505  100%
# DESCRIBE --> count    2.365050e+05
# mean     3.257231e+05
# std      9.927442e+05
# min      3.282473e+03
# 25%      1.267214e+05
# 50%      2.045521e+05
# 75%      3.162350e+05
# max      8.276367e+07
# Name: spatial_lag_sale_price_time_adj, dtype: float64
#
#
# spatial_lag_s..._adj_impr_sqft  float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean        169.798029
# std         116.873006
# min           4.125790
# 25%         102.773076
# 50%         158.388962
# 75%         215.403336
# max        6148.115379
# Name: spatial_lag_sale_price_time_adj_impr_sqft, dtype: float64
#
#
# spatial_lag_s..._adj_land_sqft  float64      236,505  100%    236,505  100%
# DESCRIBE --> count    236505.000000
# mean       1590.551280
# std        3520.165572
# min           6.379899
# 25%          55.792330
# 50%         271.991750
# 75%        1358.778260
# max       29290.372446
# Name: spatial_lag_sale_price_time_adj_land_sqft, dtype: float64
#
#
# spatial_lag_s...ime_adj_vacant  float64      236,505  100%    236,505  100%
# DESCRIBE --> count    2.365050e+05
# mean     5.054932e+05
# std      1.227545e+06
# min      1.206882e+03
# 25%      6.473734e+04
# 50%      1.697295e+05
# 75%      4.425364e+05
# max      1.207103e+07
# Name: spatial_lag_sale_price_time_adj_vacant, dtype: float64
#
#
# transmission_line_distance      Float64      233,812   99%    234,959   99%
# DESCRIBE --> count       234959.0
# mean     1827.264574
# std      1231.454187
# min              0.0
# 25%            815.0
# 50%           1640.0
# 75%           2718.0
# max           5156.0
# Name: transmission_line_distance, dtype: Float64
#
#
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_geom_complex                   bool         3,636    2%    236,505  100%                            [False, True]
# is_geom_elongated                 bool        97,242   41%    236,505  100%                            [False, True]
# is_geom_irregular                 bool       102,078   43%    236,505  100%                            [False, True]
# is_geom_triangular                bool         2,044    1%    236,505  100%                            [False, True]
# is_vacant                         bool        17,145    7%    236,505  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# block                            string      236,505  100%    236,505  100%                                    5,547
# VALUE COUNTS --> block
# 5387     982
# 5138A    928
# 5267O    839
# 6190     836
# 4778E    770
#         ...
# 1306D      1
# 1372       1
# 8480B      1
# 4469       1
# 6308       1
# Name: count, Length: 5547, dtype: Int64
#
#
# census_block                     string      236,505  100%    236,505  100%                                    9,163
# VALUE COUNTS --> census_block
# 245102604012004    832
# 245102604011000    686
# 245100203003008    622
# 245102715031000    588
# 245102720042002    475
#                   ...
# 245102602031015      1
# 245101205002023      1
# 245100402001011      1
# 245102602031018      1
# 245101202022001      1
# Name: count, Length: 9163, dtype: Int64
#
#
# census_block_group               string      236,505  100%    236,505  100%                                      642
# VALUE COUNTS --> census_block_group
# 245102401001    1342
# 245100807001    1331
# 245100302002    1262
# 245102402001    1101
# 245102501012    1020
#                 ...
# 240054404004       1
# 240054404001       1
# 240054024031       1
# 240054210001       1
# 240054012001       1
# Name: count, Length: 642, dtype: Int64
#
#
# census_tract                     string      236,505  100%    236,505  100%                                      218
# VALUE COUNTS --> census_tract
# 24510260302    2474
# 24510271200    2308
# 24510260605    2178
# 24510250500    2174
# 24510151100    2173
#                ...
# 24005403202       1
# 24005403402       1
# 24005400200       1
# 24005402403       1
# 24005421000       1
# Name: count, Length: 218, dtype: Int64
#
#
# city                             string      236,505  100%    236,505  100%                            ['baltimore']
# VALUE COUNTS --> city
# baltimore    236505
# Name: count, dtype: Int64
#
#
# lbcs_site_desc                   string      220,510   93%    220,510   93%                                        4
# VALUE COUNTS --> lbcs_site_desc
# Developed site with buildings                         219979
# Local parks and recreational sites                       530
# Developed site with crops, grazing, forestry, etc.         1
# Name: count, dtype: Int64
#
#
# lot                              string      236,471  100%    236,471  100%                                    3,080
# VALUE COUNTS --> lot
# 001     5517
# 005     4214
# 004     4176
# 006     4167
# 003     4161
#         ...
# 072T       1
# 062K       1
# 062L       1
# 062M       1
# 022R       1
# Name: count, Length: 3079, dtype: Int64
#
#
# neighborhood                     string      235,850  100%    235,850  100%                                      281
# VALUE COUNTS --> neighborhood
# CANTON                 6438
# BELAIR-EDISON          6281
# FRANKFORD              4179
# SANDTOWN-WINCHESTER    3915
# BROADWAY EAST          3824
#                        ...
# PORT COVINGTON            4
# PATTERSON PARK            3
# HERRING RUN PARK          2
# DRUID HILL PARK           2
# GREENMOUNT CEMETERY       1
# Name: count, Length: 280, dtype: Int64
#
#
# parcel_use_code                  string      236,471  100%    236,471  100%                                       12
# VALUE COUNTS --> parcel_use_code
# R     194195
# U      12152
# E      12013
# C       8646
# EC      4024
# M       2441
# I       2234
# CC       717
# CR        24
# RC        24
# A          1
# Name: count, dtype: Int64
#
#
# parcel_use_desc                  string      157,418   67%    157,418   67%                                       12
# VALUE COUNTS --> parcel_use_desc
# Residential                133093
# Exempt                      10090
# Commercial                   7158
# Exempt Commercial            3092
# Apartments                   1745
# Industrial                   1444
# Residential Condominium       696
# Commercial Condominium         65
# Commercial/Residential         23
# Residential/Commercial         11
# Agricultural                    1
# Name: count, dtype: Int64
#
#
# police_district                  string      235,816  100%    235,816  100%                                       10
# VALUE COUNTS --> police_district
# 4    43017
# 5    34665
# 2    30303
# 9    27029
# 8    25647
# 6    24796
# 3    19555
# 7    19403
# 1    11401
# Name: count, dtype: Int64
#
#
# risk_disaster                    string      236,318  100%    236,318  100%                                        5
# VALUE COUNTS --> risk_disaster
# Relatively Low         142290
# Very Low                76514
# Relatively Moderate     15343
# Relatively High          2171
# Name: count, dtype: Int64
#
#
# risk_flood                       string      234,215   99%    234,215   99%                                        4
# VALUE COUNTS --> risk_flood
# AREA OF MINIMAL FLOOD HAZARD          229342
# 0.2 PCT ANNUAL CHANCE FLOOD HAZARD      4381
# FLOODWAY                                 492
# Name: count, dtype: Int64
#
#
# section                          string      236,471  100%    236,471  100%                                       67
# VALUE COUNTS --> section
# 010    18815
# 050    14523
# 020    13966
# 040    12824
# 030    12767
#        ...
# 480      253
# 660      236
# 550      227
# 630      127
# 000        6
# Name: count, Length: 66, dtype: Int64
#
#
# ward                             string      236,505  100%    236,505  100%                                       29
# VALUE COUNTS --> ward
# 27    49761
# 26    25766
# 15    18537
# 25    14747
# 20    11868
# 09    11747
# 16    11277
# 08    11206
# 28    10227
# 13     9681
# 12     8761
# 01     6645
# 24     6131
# 07     4631
# 06     4347
# 19     3807
# 11     3539
# 02     3444
# 21     3164
# 14     2876
# 23     2867
# 03     2541
# 18     2222
# 22     1700
# 04     1658
# 10     1469
# 17     1407
# 05      473
# 50        6
# Name: count, dtype: Int64
#
#
# zip                              string      236,505  100%    236,505  100%                                       41
# VALUE COUNTS --> zip
# 21215    19630
# 21224    19212
# 21218    18155
# 21230    17358
# 21213    16212
# 21217    15203
# 21223    14355
# 21229    13864
# 21216    12205
# 21206    12050
# 21212     8104
# 21211     7753
# 21214     7691
# 21205     7216
# 21202     7192
# 21239     7004
# 21231     6705
# 21225     4700
# 21201     4425
# 21210     4053
# 21207     3763
# 21209     3475
# 21234     2582
# 21226     1750
# 21222      875
# 21208      355
# 21227      192
# 21228      153
# 21237      134
# 21236       86
# 21221       17
# 21204       14
# 21220        6
# 21286        4
# 21219        3
# 21250        2
# 21240        2
# 21244        2
# 21298        1
# 21233        1
# 20002        1
# Name: count, dtype: Int64
#
#
# zoning                           string      236,504  100%    236,504  100%                                       71
# VALUE COUNTS --> zoning
# R-8         71945
# R-6         55341
# R-7         21792
# R-5         18801
# R-3         18596
#             ...
# R-5/D-MU        3
# OS/W-1          2
# DR-3.5          1
# RO              1
# C1              1
# Name: count, Length: 70, dtype: Int64
#
#
# zoning_desc                      string      236,502  100%    236,502  100%                                       45
# VALUE COUNTS --> zoning_desc
# Row House And Multi Family Residential                                                 171181
# Detached Residential                                                                    30122
# Detached And Semi Detached Residential                                                   8774
# Neighborhood Business                                                                    5899
# Community Commercial                                                                     3754
# Office Residential                                                                       2603
# Downtown Core Subdistrict                                                                2295
# Community Commercial Waterfront Overlay District                                         1538
# General Industrial                                                                       1469
# Light Industrial                                                                         1243
# Open Space                                                                                934
# Transit Oriented Development                                                              917
# Industrial Mixed Use                                                                      657
# Office Residential Row House Mixed Use Overlay District                                   521
# Row House And Multi Family Residential Mixed Use Overlay District                         515
# General Commercial                                                                        460
# Bio Science Campus                                                                        436
# Row House And Multi Family Residential Waterfront Overlay District                        426
# Port Covington                                                                            416
# Maritime Industrial                                                                       384
# Hospital Campus                                                                           384
# Educational Campus                                                                        305
# Heavy Commercial                                                                          255
# Downtown Historic And Traditional Subdistrict                                             147
# Downtown Traditional Office Subdistrict                                                   146
# Detached And Semi Detached Residential Dwelling Mixed Use Overlay District                117
# Downtown Howard Street Mixed Use Subdistrict                                              107
# Detached Residential Dwelling Mixed Use Overlay District                                  106
# Neighborhood Business And Entertainment                                                   103
# Office Industrial Campus                                                                   94
# Downtown East Subdistrict                                                                  74
# Neighborhood Business Village Center District                                              40
# Downtown Inner Harbor Subdistrict                                                          15
# Downtown Traditional Office Adult Use Overlay Subdistrict                                  12
# Downtown Government Center Subdistrict                                                     11
# Downtown Core Adult Use Overlay Subdistrict                                                11
# Transit Oriented Development Waterfront Overlay District                                   11
# Neighborhood Business And Entertainment Waterfront Overlay District                         6
# Density Residential 5.5 Dwelling Units Per Acre                                             6
# Row House And Multi Family Residential Detached Dwelling Mixed Use Overlay District         3
# Open Space Waterfront Overlay District                                                      2
# Density Residential 3.5 Dwelling Units Per Acre                                             1
# Residential Office 5.5 Dwelling Units Per Acre                                              1
# Local Commercial                                                                            1
# Name: count, dtype: Int64
#
#
# zoning_subtype                   string      236,502  100%    236,502  100%                                       14
# VALUE COUNTS --> zoning_subtype
# Multi Family               171181
# Single Family               38896
# Neighborhood Commercial      9796
# Mixed Use                    4159
# Overlay                      3268
# Special Commercial           2798
# Industrial                   1853
# Special                      1541
# Light Industrial             1243
# Office                        934
# General Commercial            715
# Retail Commercial             111
# Two Family                      7
# Name: count, dtype: Int64
#
#
# zoning_type                      string      236,502  100%    236,502  100%                                        7
# VALUE COUNTS --> zoning_type
# Residential    210084
# Commercial      14354
# Mixed            4159
# Overlay          3268
# Industrial       3096
# Special          1541
# Name: count, dtype: Int64
#
#
# zoning_url                       string      236,502  100%    236,502  100%                                        4
# VALUE COUNTS --> zoning_url
# https://www.zoneomics.com/code/baltimore-MD                                  236493
# https://library.municode.com/md/baltimore_county/codes/zoning_regulations         8
# https://www.zoneomics.com/code/anne-arundel-county-unincorporated-MD              1
# Name: count, dtype: Int64
#
#
#
# ============================== ========== ========== ===== ========== ===== ========================================
#          IMPROVEMENT
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_bldg_area_finished_sqft    Float64      169,012   71%    234,908   99%
# DESCRIBE --> count       234908.0
# mean      1240.14507
# std      1933.016219
# min              0.0
# 25%              0.0
# 50%           1144.0
# 75%           1440.0
# max          32760.0
# Name: assr_bldg_area_finished_sqft, dtype: Float64
#
#
# assr_impr_value                 Float64      206,953   88%    236,505  100%
# DESCRIBE --> count          236505.0
# mean      163036.485694
# std      1626019.698431
# min                 0.0
# 25%             33000.0
# 50%             90600.0
# 75%            140200.0
# max         275420700.0
# Name: assr_impr_value, dtype: Float64
#
#
# bldg_age_years                  Float64      178,597   76%    236,505  100%
# DESCRIBE --> count     236505.0
# mean     67.943794
# std      45.692147
# min            0.0
# 25%            9.0
# 50%           80.0
# 75%          105.0
# max          247.0
# Name: bldg_age_years, dtype: Float64
#
#
# bldg_area_finished_sqft         Float64      219,360   93%    236,505  100%
# DESCRIBE --> count       236505.0
# mean     1722.620607
# std      2549.863907
# min              0.0
# 25%           1024.0
# 50%           1240.0
# 75%           1551.0
# max          32760.0
# Name: bldg_area_finished_sqft, dtype: Float64
#
#
# bldg_area_fin...ed_sqft_zillow  Float64      130,236   55%    150,072   63%
# DESCRIBE --> count       150072.0
# mean     1333.625187
# std       4392.55948
# min             -1.0
# 25%            978.0
# 50%           1235.0
# 75%           1587.0
# max        1459459.0
# Name: bldg_area_finished_sqft_zillow, dtype: Float64
#
#
# bldg_area_footprint_sqft        float64      219,360   93%    236,505  100%
# DESCRIBE --> count    2.365050e+05
# mean     6.531301e+03
# std      4.322844e+04
# min      0.000000e+00
# 25%      6.149589e+02
# 50%      7.848097e+02
# 75%      1.193031e+03
# max      1.178270e+06
# Name: bldg_area_footprint_sqft, dtype: float64
#
#
# bldg_count                      Float64      214,122   91%    236,505  100%
# DESCRIBE --> count     236505.0
# mean      2.317562
# std      15.633133
# min            0.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max          224.0
# Name: bldg_count, dtype: Float64
#
#
# bldg_quality_num                Float64      106,631   45%    123,776   52%
# DESCRIBE --> count    123776.0
# mean     3.059866
# std      1.500734
# min           0.0
# 25%           3.0
# 50%           3.0
# 75%           4.0
# max           9.0
# Name: bldg_quality_num, dtype: Float64
#
#
# bldg_rooms_bath                 Float64      134,728   57%    153,275   65%
# DESCRIBE --> count    153275.0
# mean     1.616786
# std      1.131326
# min           0.0
# 25%           1.0
# 50%           1.5
# 75%           2.0
# max         115.0
# Name: bldg_rooms_bath, dtype: Float64
#
#
# bldg_rooms_bed                  Float64       81,230   34%     99,323   42%
# DESCRIBE --> count     99323.0
# mean     2.535526
# std      1.496105
# min           0.0
# 25%           2.0
# 50%           3.0
# 75%           3.0
# max          46.0
# Name: bldg_rooms_bed, dtype: Float64
#
#
# bldg_stories                    Float64        8,724    4%     25,869   11%
# DESCRIBE --> count     25869.0
# mean     0.777301
# std      1.611291
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           1.0
# max          43.0
# Name: bldg_stories, dtype: Float64
#
#
# bldg_units                      Float64          261    0%    236,505  100%
# DESCRIBE --> count    236505.0
# mean     0.011818
# std       2.01718
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max         900.0
# Name: bldg_units, dtype: Float64
#
#
# bldg_year_built                 Float64      178,597   76%    195,742   83%
# DESCRIBE --> count       195742.0
# mean     1765.537687
# std       547.680524
# min              0.0
# 25%           1920.0
# 50%           1925.0
# 75%           1950.0
# max           2023.0
# Name: bldg_year_built, dtype: Float64
#
#
# exempt_impr_value               Float64        7,170    3%    236,490  100%
# DESCRIBE --> count          236490.0
# mean       60795.687822
# std      2870688.614701
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max         740662700.0
# Name: exempt_impr_value, dtype: Float64
#
#
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# inferred_bldg..._finished_sqft    bool        50,348   21%    236,505  100%                            [False, True]
# is_bldg_vacant                   object      219,345   93%    236,490  100%                       [True, False, nan]
# is_usps_vacant                    bool       219,360   93%    236,505  100%                            [True, False]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# bldg_class                       string      168,114   71%    168,114   71%                                       11
# VALUE COUNTS --> bldg_class
# TOWNHOUSE            77843
# SINGLE_FAMILY        67454
# UNKNOWN              17145
# CONDO                 2501
# MULTI_FAMILY          1673
# APARTMENT              905
# HOME_TYPE_UNKNOWN      504
# LOT                     66
# MANUFACTURED            15
# FOR_RENT                 8
# Name: count, dtype: Int64
#
#
# bldg_construction                string      118,762   50%    118,762   50%                                       22
# VALUE COUNTS --> bldg_construction
# CNST Brick               58446
# CNST Frame               18195
# UNKNOWN                  17145
# CNST Siding              13949
# CNST Shingle Asbestos     3351
# CNST Stucco               2590
# CNST Shingle Wood         1808
# CNST Block                 869
# CNST 1/2 Brick Frame       619
# CNST Stone                 560
# CNST 1/2 Brick Siding      547
# CNST 1/2 Stone Frame       273
# CNST Brick Common          137
# CNST Brick Face             79
# CNST Metal                  44
# CNST Brick Veneer           42
# CNST 1/2 Stone Siding       41
# CNST Concrete               28
# CNST Brick and Metal        23
# CNST Vinyl                   8
# CNST Wood                    8
# Name: count, dtype: Int64
#
#
# bldg_desc                        string      154,164   65%    154,164   65%                                      109
# VALUE COUNTS --> bldg_desc
# DWEL Center Unit                     47358
# DWEL Rental Dwelling                 39166
# DWEL Standard Unit                   22401
# DWEL End Unit                        18264
# UNKNOWN                              17145
#                                      ...
# STORE Shopping Center/ Regional          1
# OTHER Special Use                        1
# REC Handball / Racquetball Courts        1
# HOUSING Residence                        1
# WAREHOUSE Cold Storage Facility          1
# Name: count, Length: 108, dtype: Int64
#
#
# bldg_quality_txt                 string      236,505  100%    236,505  100%                                       11
# VALUE COUNTS --> bldg_quality_txt
# None                 112729
# 3 - Fair              71440
# UNKNOWN               17145
# 4 - Average           16979
# 5 - Above Average     12019
# 6 - Good               5105
# 7 - Very Good           484
# 2 - Economy             303
# 8 - Excellent           182
# 1 - Low                  93
# 9 - Superior             26
# Name: count, dtype: Int64
#
#
# bldg_style                       string      124,775   53%    124,775   53%                                      134
# VALUE COUNTS --> bldg_style
# STRY Townhouse-Center Unit 2 Story With Basem    39777
# UNKNOWN                                          17145
# STRY Townhouse-End Unit 2 Story With Basement    14828
# STRY 2 Story With Basement                       14059
# STRY Townhouse-Center Unit 3 Story With Basem     6768
#                                                  ...
# STRY Townhouse-Center Unit 1.5 Story No Basem        1
# STORE Finish Neighborhood Shopping Center            1
# HOUSING Residence                                    1
# STORE Shopping Center / Regional                     1
# WAREHOUSE Cold Storage Facility                      1
# Name: count, Length: 133, dtype: Int64
#
#
# lbcs_activity_desc               string      228,637   97%    228,637   97%                                        7
# VALUE COUNTS --> lbcs_activity_desc
# Household                                            201860
# UNKNOWN                                               17145
# Shopping, business, or trade                           8491
# Industrial, manufacturing, and waste-related           1045
# Promenading and other activities in parks                95
# Farming, tilling, plowing, harvesting, or related         1
# Name: count, dtype: Int64
#
#
# lbcs_function_desc               string      228,637   97%    228,637   97%                                        7
# VALUE COUNTS --> lbcs_function_desc
# Private household                             201860
# UNKNOWN                                        17145
# General sales or services                       8491
# Manufacturing and wholesale trade               1045
# Natural and other recreational parks              95
# Agriculture, forestry, fishing and hunting         1
# Name: count, dtype: Int64
#
#
# lbcs_structure_desc              string      228,542   97%    228,542   97%                                        6
# VALUE COUNTS --> lbcs_structure_desc
# Residential buildings                                    200128
# UNKNOWN                                                   17145
# Commercial buildings and other specialized structures      8491
# Multifamily structures                                     1733
# Industrial buildings and structures                        1045
# Name: count, dtype: Int64
#
#
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_market_value               Float64      219,397   93%    236,505  100%
# DESCRIBE --> count          236505.0
# mean       217293.62972
# std      1843382.166588
# min                 0.0
# 25%             50100.0
# 50%            125000.0
# 75%            198600.0
# max         298701500.0
# Name: assr_market_value, dtype: Float64
#
#
# credit_city_homestead           Float64          221    0%    233,674   99%
# DESCRIBE --> count    233674.0
# mean     0.086484
# std      3.002404
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max         127.0
# Name: credit_city_homestead, dtype: Float64
#
#
# credit_state_homestead          Float64        5,355    2%    236,471  100%
# DESCRIBE --> count     236471.0
# mean     41.627369
# std      328.73314
# min            0.0
# 25%            0.0
# 50%            0.0
# 75%            0.0
# max         7080.0
# Name: credit_state_homestead, dtype: Float64
#
#
# sale_age_days                    Int64       236,502  100%    236,502  100%
# DESCRIBE --> count        236502.0
# mean      6764.144109
# std      11812.765221
# min               6.0
# 25%            1254.0
# 50%            3647.0
# 75%            7898.0
# max           83275.0
# Name: sale_age_days, dtype: Float64
#
#
# sale_month                      float64      236,502  100%    236,502  100%
# DESCRIBE --> count    236502.000000
# mean          6.448030
# std           3.442357
# min           1.000000
# 25%           4.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Name: sale_month, dtype: float64
#
#
# sale_price                      Float64      168,569   71%    236,505  100%
# DESCRIBE --> count          236505.0
# mean      263389.880666
# std      2351615.963365
# min                 0.0
# 25%                 0.0
# 50%             56900.0
# 75%            175500.0
# max         344273453.0
# Name: sale_price, dtype: Float64
#
#
# sale_quarter                    float64      236,502  100%    236,502  100%
# DESCRIBE --> count    236502.000000
# mean          2.484508
# std           1.112800
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max           4.000000
# Name: sale_quarter, dtype: float64
#
#
# sale_year                       float64      236,502  100%    236,502  100%
# DESCRIBE --> count    236502.000000
# mean       2005.989700
# std          32.281852
# min        1797.000000
# 25%        2003.000000
# 50%        2015.000000
# 75%        2021.000000
# max        2024.000000
# Name: sale_year, dtype: float64
#
#
# zestimate                       Float64      125,240   53%    125,240   53%
# DESCRIBE --> count         125240.0
# mean     238674.648675
# std      168386.836195
# min            12500.0
# 25%           142100.0
# 50%           195700.0
# 75%           284400.0
# max          6546200.0
# Name: zestimate, dtype: Float64
#
#
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_vacant                         bool        17,145    7%    236,505  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assess_grp                       string      236,471  100%    236,471  100%                    ['2', <NA>, '3', '1']
# VALUE COUNTS --> assess_grp
# 2    90492
# 3    74499
# 1    71480
# Name: count, dtype: Int64
#
#
# assessor                         string      236,384  100%    236,384  100%                                       46
# VALUE COUNTS --> assessor
# 316    22540
# 322    20760
# 321    20332
# 314    19983
# 317    18408
# 305    16836
# 332    14943
# 331    14454
# 313    12336
# 310     7844
# 348     7630
# 376     6904
# 339     6454
# 394     6159
# 388     4698
# 340     4446
# 379     4008
# 329     3814
# 377     3788
# 346     3670
# 302     3609
# 301     3503
# 392     2098
# 399     2056
# 311     1998
# 320     1362
# 304      746
# 380      475
# 306      200
# 315      130
# 383      118
# 333       48
# 325        8
# 308        6
# 326        4
# 342        4
# 356        2
# 398        2
# 382        2
# 386        1
# 355        1
# 319        1
# 372        1
# 327        1
# 354        1
# Name: count, dtype: Int64
#
#
# exempt_code                      string      236,470  100%    236,470  100%                                       81
# VALUE COUNTS --> exempt_code
# 00    219587
# 56      6931
# 51      1709
# 70      1422
# 54      1253
#        ...
# 67         1
# 85         1
# 47         1
# 94         1
# 37         1
# Name: count, Length: 80, dtype: Int64
#
#
# exempt_type                      string           32    0%         32    0%                              [<NA>, 'E']
# VALUE COUNTS --> exempt_type
# E    32
# Name: count, dtype: Int64
#
#
# key                              string      236,505  100%    236,505  100%                                  236,505
# VALUE COUNTS --> key
# 0001001    1
# 0001033    1
# 0002061    1
# 0001030    1
# 0001003    1
#           ..
# 8491026    1
# PSC0010    1
# PSC0020    1
# PSC0065    1
# PSC0085    1
# Name: count, Length: 236505, dtype: Int64
#
#
# lbcs_ownership_desc              string      199,628   84%    199,628   84%                                       10
# VALUE COUNTS --> lbcs_ownership_desc
# Private persons and private joint ownership    143297
# Businesses and commercial entities              43547
# City, Village, Township, etc.                    6883
# Private trusts                                   3042
# Nonprofit religious                              1766
# State government                                  641
# Nonprofit educational                             294
# Federal government                                140
# County, Parish, Province, etc.                     18
# Name: count, dtype: Int64
#
#
# mail_city                        string      170,271   72%    170,271   72%                                    2,980
# VALUE COUNTS --> mail_city
# BALTIMORE        125761
# WASHINGTON         1737
# ELLICOTT CITY      1543
# OWINGS MILLS       1375
# SILVER SPRING      1154
#                   ...
# BETLSVILLE            1
# PEMBROKE              1
# ALACHUA               1
# MINERAL               1
# BAYTOWN               1
# Name: count, Length: 2979, dtype: Int64
#
#
# mail_state                       string      170,414   72%    170,414   72%                                       87
# VALUE COUNTS --> mail_state
# MD     153125
# VA       3188
# NY       2606
# PA       1930
# DC       1758
#         ...
# ST          1
# AA          1
# SW          1
# JPN         1
# PK          1
# Name: count, Length: 86, dtype: Int64
#
#
# mail_zip                         string      221,077   93%    221,077   93%                                   22,951
# VALUE COUNTS --> mail_zip
# 21202         10064
# 21215          6545
# 21218          5769
# 21230          5464
# 21224          5137
#               ...
# 21146-4047        1
# 21042-2163        1
# 21207-7035        1
# 21207-6104        1
# 21032-1842        1
# Name: count, Length: 22950, dtype: Int64
#
#
# owner_vs_renter                  string      236,505  100%    236,505  100%                          ['N', 'H', 'D']
# VALUE COUNTS --> owner_vs_renter
# N    124975
# H    110998
# D       532
# Name: count, dtype: Int64
#
#
# ownership_mode                   string      207,412   88%    207,412   88%                    ['F', <NA>, 'L', '3']
# VALUE COUNTS --> ownership_mode
# F    147854
# L     59557
# 3         1
# Name: count, dtype: Int64
#
#
# parcel_value_type                string      236,505  100%    236,505  100%                               ['MARKET']
# VALUE COUNTS --> parcel_value_type
# MARKET    236505
# Name: count, dtype: Int64
#
#
# sale_date                      datetime64[ns]    236,502  100%    236,502  100%                                   15,443
# VALUE COUNTS --> sale_date
# 1797-01-01    4416
# 1956-05-31    1515
# 2021-03-04     308
# 2005-08-10     291
# 2022-04-15     274
#               ...
# 1962-11-01       1
# 1951-08-21       1
# 1948-06-26       1
# 1963-05-21       1
# 1972-08-10       1
# Name: count, Length: 15442, dtype: int64
#
#
# sale_year_month                  object      236,505  100%    236,505  100%                                    1,258
# VALUE COUNTS --> sale_year_month
# 1797-01    4416
# 2021-03    2056
# 2021-04    1960
# 2024-10    1919
# 2022-11    1859
#            ...
# 1907-08       1
# 1893-06       1
# 1936-02       1
# 1907-11       1
# 1936-12       1
# Name: count, Length: 1258, dtype: int64
#
#
# sale_year_quarter                object      236,505  100%    236,505  100%                                      507
# VALUE COUNTS --> sale_year_quarter
# 2022Q2    5073
# 2022Q4    4851
# 2023Q1    4833
# 2023Q2    4723
# 2024Q4    4533
#           ...
# 1845Q2       1
# 1919Q2       1
# 1917Q2       1
# 1879Q3       1
# 1862Q3       1
# Name: count, Length: 507, dtype: int64
#
#
# status_owner                     string      236,471  100%    236,471  100%                    ['N', 'H', <NA>, 'D']
# VALUE COUNTS --> status_owner
# N    125116
# H    110831
# D       524
# Name: count, dtype: Int64
#
#
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# address                          object      229,593   97%    229,593   97%                                  226,825
# address_mail                     object      236,471  100%    236,471  100%                                  175,679
# geometry                        geometry     236,505  100%    236,505  100%                                  222,588
# key2                             object      155,045   66%    155,045   66%                                  154,875
#
# EXAMINING SALES...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# spatial_lag_s...price_time_adj  float64       53,711  100%     53,711  100%
# DESCRIBE --> count    5.371100e+04
# mean     2.968215e+05
# std      9.163528e+05
# min      3.282473e+03
# 25%      1.275873e+05
# 50%      2.136965e+05
# 75%      3.343513e+05
# max      8.276367e+07
# Name: spatial_lag_sale_price_time_adj, dtype: float64
#
#
# spatial_lag_s..._adj_impr_sqft  float64       53,711  100%     53,711  100%
# DESCRIBE --> count    53711.000000
# mean       175.310285
# std        111.256704
# min          4.125790
# 25%        103.088498
# 50%        164.958215
# 75%        232.541750
# max       6148.115379
# Name: spatial_lag_sale_price_time_adj_impr_sqft, dtype: float64
#
#
# spatial_lag_s..._adj_land_sqft  float64       53,711  100%     53,711  100%
# DESCRIBE --> count    53711.000000
# mean      1605.677070
# std       3344.689321
# min          6.798315
# 25%         59.796346
# 50%        310.832243
# 75%       1549.102317
# max      29290.372446
# Name: spatial_lag_sale_price_time_adj_land_sqft, dtype: float64
#
#
# spatial_lag_s...ime_adj_vacant  float64       53,711  100%     53,711  100%
# DESCRIBE --> count    5.371100e+04
# mean     4.454884e+05
# std      9.569374e+05
# min      1.206882e+03
# 25%      7.272552e+04
# 50%      1.872744e+05
# 75%      4.991076e+05
# max      1.207103e+07
# Name: spatial_lag_sale_price_time_adj_vacant, dtype: float64
#
#
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# sale_age_days                    Int64        53,832  100%     53,832  100%
# DESCRIBE --> count       53832.0
# mean     800.623867
# std       488.81856
# min          -133.0
# 25%           397.0
# 50%           803.0
# 75%          1185.0
# max          1826.0
# Name: sale_age_days, dtype: Float64
#
#
# sale_month                      float64       53,832  100%     53,832  100%
# DESCRIBE --> count    53832.000000
# mean         6.347173
# std          3.505693
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# Name: sale_month, dtype: float64
#
#
# sale_price                      Float64       53,837  100%     53,837  100%
# DESCRIBE --> count           53837.0
# mean      292324.611475
# std      1707345.248264
# min               100.0
# 25%            105000.0
# 50%            196000.0
# 75%            300000.0
# max         191080598.0
# Name: sale_price, dtype: Float64
#
#
# sale_price_time_adj             Float64       53,837  100%     53,837  100%
# DESCRIBE --> count             53837.0
# mean        327064.599355
# std          1976503.0774
# min            112.152853
# 25%         112237.547984
# 50%         216924.427313
# 75%          339729.70531
# max      233738934.505413
# Name: sale_price_time_adj, dtype: Float64
#
#
# sale_quarter                    float64       53,832  100%     53,832  100%
# DESCRIBE --> count    53832.000000
# mean         2.463015
# std          1.137190
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max          4.000000
# Name: sale_quarter, dtype: float64
#
#
# sale_year                       float64       53,832  100%     53,832  100%
# DESCRIBE --> count    53832.000000
# mean      2022.325364
# std          1.342184
# min       2020.000000
# 25%       2021.000000
# 50%       2022.000000
# 75%       2023.000000
# max       2025.000000
# Name: sale_year, dtype: float64
#
#
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# vacant_sale                      object          512    1%     53,837  100%                            [False, True]
# valid_for_land_ratio_study        bool           512    1%     53,837  100%                            [False, True]
# valid_for_ratio_study             bool        53,205   99%     53,837  100%                            [True, False]
# valid_sale                       object       53,837  100%     53,837  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string       53,837  100%     53,837  100%                                   47,865
# VALUE COUNTS --> key
# 4626A078    3
# 4163A045    3
# 1707092     3
# 1874119     3
# 5417A016    3
#            ..
# 7654G065    1
# 7654G108    1
# 7654G119    1
# 7654G120    1
# 8491021     1
# Name: count, Length: 47865, dtype: Int64
#
#
# key_sale                         string       53,837  100%     53,837  100%                                   53,837
# VALUE COUNTS --> key_sale
# 0001005---2021-06-04     1
# 0003052---2023-08-28     1
# 0002058---2024-01-18     1
# 0001033F---2021-01-15    1
# 0001008---2021-12-15     1
#                         ..
# 8488011---2024-09-09     1
# 8489010---2022-07-14     1
# 8490002---2021-11-16     1
# 8490006---2020-10-13     1
# 8491021---2023-07-07     1
# Name: count, Length: 53837, dtype: Int64
#
#
# sale_date                      datetime64[ns]     53,832  100%     53,832  100%                                    1,326
# VALUE COUNTS --> sale_date
# 2022-08-17    125
# 2025-01-09    125
# 2023-10-10    115
# 2021-04-29    111
# 2023-11-14    109
#              ...
# 2020-03-18      1
# 2021-09-04      1
# 2021-10-17      1
# 2021-03-28      1
# 2020-11-29      1
# Name: count, Length: 1325, dtype: int64
#
#
# sale_year_month                  object       53,837  100%     53,837  100%                                       64
# VALUE COUNTS --> sale_year_month
# 2021-04    1346
# 2021-03    1292
# 2022-08    1238
# 2024-10    1222
# 2021-11    1222
#            ...
# 2020-09     303
# 2020-08     277
# 2020-04     181
# NaT           5
# 2025-05       1
# Name: count, Length: 64, dtype: int64
#
#
# sale_year_quarter                object       53,837  100%     53,837  100%                                       23
# VALUE COUNTS --> sale_year_quarter
# 2021Q4    3375
# 2022Q2    3297
# 2023Q1    3269
# 2021Q2    3216
# 2022Q3    3197
# 2023Q2    3183
# 2022Q4    3174
# 2024Q4    2996
# 2022Q1    2896
# 2021Q3    2748
# 2024Q2    2730
# 2023Q3    2703
# 2021Q1    2658
# 2023Q4    2636
# 2024Q1    2603
# 2024Q3    2600
# 2025Q1    1792
# 2020Q4    1376
# 2020Q1    1340
# 2020Q3    1121
# 2020Q2     921
# NaT          5
# 2025Q2       1
# Name: count, dtype: int64
#
#
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# convey_type                      object       53,837  100%     53,837  100%                                        2
# sale_grantor                     object       53,835  100%     53,835  100%                                   43,893
# sale_record                     float64       53,837  100%     53,837  100%                          [1.0, 2.0, 3.0]

# %% [markdown]
# ## 4.3 Look at it on a map
#
# - Go to your `out/look/` folder
# - There should be parquets there
# - Drop them into ArcGIS, QGIS, or Felt
# - Look at your location fields and make sure they make sense

# %% [markdown]
# # 5. Tag modeling groups
# - Separates rows into groups like "single family", "townhomes" and "commercial" as specified by the user
# - These groups will guide all further processing

# %%
settings = load_settings()
sales_univ_pair = from_checkpoint("1-assemble-04-tag_modeling_groups", tag_model_groups_sup,
    {
        "sup": sales_univ_pair, 
        "settings": settings, 
        "verbose": verbose
    }
)
# Out:
# Len univ before = 236505
# Len sales before = 53837 after = 53837
# Overall
# --> 236,505 parcels
# --> 53,837 sales
# Assigning model group condos...
# common_area -->  False
# Assigning model group apartments...
# common_area -->  False
# Assigning model group industrial...
# common_area -->  False
# Assigning model group rowhome...
# common_area -->  False
# Assigning model group single_family...
# common_area -->  False
# Assigning model group commercial...
# common_area -->  False
#  --> 0 parcels had their model group changed.
# Condos
# --> 12,869 parcels
# --> 2,979 sales
# ----> 2,974 improved sales
# ----> 5 vacant sales
# Apartments
# --> 3,713 parcels
# --> 374 sales
# ----> 359 improved sales
# ----> 15 vacant sales
# Industrial
# --> 4,318 parcels
# --> 509 sales
# ----> 483 improved sales
# ----> 26 vacant sales
# Rowhome/townhouse
# --> 167,977 parcels
# --> 40,788 sales
# ----> 40,537 improved sales
# ----> 251 vacant sales
# Single-family
# --> 39,122 parcels
# --> 8,722 sales
# ----> 8,585 improved sales
# ----> 137 vacant sales
# Commercial
# --> 24,041 parcels
# --> 3,768 sales
# ----> 3,708 improved sales
# ----> 60 vacant sales

# %% [markdown]
# # 6. Write out results

# %%
write_notebook_output_sup(sales_univ_pair, "1-assemble")
# Out:
# Results written to:
# ...out/1-assemble-sup.pickle
# ...out/look/1-assemble-universe.parquet
# ...out/look/1-assemble-sales.parquet
# ...out/look/1-assemble-sales-hydrated.parquet

# %% [markdown]
# # 7. Look at it on a map!
# - Take the files output in the previous step and put them in a map viewer like QGIS, ArcGIS, or Felt
# - Look at them with your eyeballs
# - Make sure the data looks correct
# - If not, go back and fix it!
# - Don't proceed to the next step until everything looks right

# %%
# Let's examine the sales and universe data
def analyze_data_quality(sales_univ_pair):
   
    sales_df = sales_univ_pair["sales"]
    universe_df = sales_univ_pair["universe"]
    # Print head of top ten assr_bldg_area_finished_sqft
    print("\n=== Top 10 Properties by Building Area ===")
    if 'assr_bldg_area_finished_sqft' in universe_df.columns:
        # Sort by building area in descending order and get top 10
        top_area_properties = universe_df.sort_values(by='assr_bldg_area_finished_sqft', ascending=False).head(10)
        
        # Select relevant columns to display
        columns_to_display = ['key', 'assr_bldg_area_finished_sqft', 'address', 'model_group']
        display_columns = [col for col in columns_to_display if col in top_area_properties.columns]
        
        print(f"\nTop 10 properties by assr_bldg_area_finished_sqft:")
        print(top_area_properties[display_columns])
    else:
        print("Column 'assr_bldg_area_finished_sqft' not found in the dataset")

    print("=== B&D Sales Check ===")
    bd_sales = sales_df[sales_df['sale_grantor'].str.contains('B&D', na=False, case=False)]
    if len(bd_sales) > 0:
        print(f"\nFound {len(bd_sales)} B&D sales:")
        print(bd_sales[['key', 'sale_grantor', 'sale_price', 'sale_date', 'convey_type']].head())
    else:
        print("No B&D sales found (good!)")
        
    print("\n=== Specific Parcel Price Tweak Check ===")
    # Check some of the specific parcel tweaks from settings.json
    parcels_to_check = [
        "1654043---2023-05-01",
        "1846082---2024-12-02",
        "6434025H---2023-02-08"
    ]
    tweaked_sales = sales_df[sales_df['key_sale'].isin(parcels_to_check)]
    if len(tweaked_sales) > 0:
        print("\nFound tweaked parcels:")
        print(tweaked_sales[['key_sale', 'sale_price', 'sale_date']].head())
    else:
        print("No tweaked parcels found")
        
    print("\n=== Rowhome Analysis ===")
    # Check for Commercial (C) use codes in rowhome zoning
    rowhome_commercial = universe_df[
        (universe_df['model_group'] == 'rowhome') & 
        (universe_df['parcel_use_code'] == 'C')
    ]
    print(f"\nRowhomes with Commercial use code: {len(rowhome_commercial)}")
    if len(rowhome_commercial) > 0:
        print("\nSample of rowhomes with commercial use:")
        print(rowhome_commercial[['key', 'parcel_use_code', 'zoning_desc', 'model_group']].head())
    
    print("\n=== Model Group Distribution ===")
    print("\nUniverse model group counts:")
    print(universe_df['model_group'].value_counts())
    
    print("\nSales model group counts:")
    sales_with_model_group = sales_df.merge(
        universe_df[['key', 'model_group']], 
        on='key', 
        how='left'
    )
    print(sales_with_model_group['model_group'].value_counts())

# Run the analysis
analyze_data_quality(sales_univ_pair)
# Out:
# === Top 10 Properties by Building Area ===
#
# Top 10 properties by assr_bldg_area_finished_sqft:
#               key  assr_bldg_area_finished_sqft               address  \
# 63478     1807001                       32760.0     1429 ALICEANNA ST
# 95040     2846006                       32760.0    2912 GARRISON BLVD
# 227980  7900F001A                       32722.0          903 COOKS LN
# 40029     1236001                       32588.0     700 E MONUMENT ST
# 228389   7993001B                       32506.0  701 N CHAPEL GATE LN
# 198112    6065013                       32493.0      4801 LORELLY AVE
# 94470     2812011                       32484.0    2200 GARRISON BLVD
# 32569     0969004                       32472.0       611 W OSTEND ST
# 32076     0965001                       32468.0     1201 S CHARLES ST
# 117414   3642D003                       32440.0        2606 SISSON ST
#
#        model_group
# 63478   industrial
# 95040   apartments
# 227980  apartments
# 40029   industrial
# 228389  apartments
# 198112  apartments
# 94470   commercial
# 32569   industrial
# 32076   apartments
# 117414  industrial
# === B&D Sales Check ===
#
# Found 11 B&D sales:
#            key            sale_grantor  sale_price  sale_date  \
# 3306  0299043A   B&D PHASE III (2) LLC    240000.0 2024-04-05
# 3307  0299044A   B&D PHASE III (2) LLC    245000.0 2023-12-12
# 3308  0299045A   B&D PHASE III (2) LLC    245000.0 2024-02-21
# 3309  0299046A   B&D PHASE III (2) LLC    245000.0 2024-01-16
# 3346   0302020  B&D PHASE III (2), LLC    202999.0 2021-03-16
#
#                                      convey_type
# 3306  Private arms-length transfer, Improved (1)
# 3307  Private arms-length transfer, Improved (1)
# 3308  Private arms-length transfer, Improved (1)
# 3309  Private arms-length transfer, Improved (1)
# 3346  Private arms-length transfer, Improved (1)
#
# === Specific Parcel Price Tweak Check ===
#
# Found tweaked parcels:
#                     key_sale  sale_price  sale_date
# 11591   1654043---2023-05-01    160000.0 2023-05-01
# 15569   1846082---2024-12-02    300000.0 2024-12-02
# 47853  6434025H---2023-02-08    422900.0 2023-02-08
#
# === Rowhome Analysis ===
#
# Rowhomes with Commercial use code: 0
#
# === Model Group Distribution ===
#
# Universe model group counts:
# model_group
# rowhome          160762
# single_family     38706
# commercial        14849
# condos            12869
# industrial         4301
# apartments         3713
# UNKNOWN            1305
# Name: count, dtype: int64
#
# Sales model group counts:
# model_group
# rowhome          39105
# single_family     8612
# condos            2979
# commercial        2060
# industrial         507
# apartments         374
# UNKNOWN             74
# Name: count, dtype: int64

# %%
# Find sales with both "CITY" and "MAYOR" in the grantor name
sales_df = sales_univ_pair["sales"]
city_mayor_sales = sales_df[
    sales_df['sale_grantor'].str.contains('CITY', na=False, case=False) & 
    sales_df['sale_grantor'].str.contains('MAYOR', na=False, case=False)
]

print("\n=== Sales with 'CITY' and 'MAYOR' in Grantor Name ===")
if len(city_mayor_sales) > 0:
    print(f"Found {len(city_mayor_sales)} sales with both 'CITY' and 'MAYOR' in grantor name:")
    
    # Display sample of these sales
    print("\nSample of sales with 'CITY' and 'MAYOR' in grantor name:")
    print(city_mayor_sales[['key', 'sale_grantor', 'sale_price', 'sale_date', 'convey_type']].head(10))
    
    # Group by grantor name and sale price, then count occurrences
    print("\nCounts of each sale price by grantor name containing 'CITY' and 'MAYOR':")
    grantor_price_counts = city_mayor_sales.groupby(['sale_grantor', 'sale_price']).size().reset_index(name='count')
    
    # Sort by grantor name and then by count (descending)
    grantor_price_counts = grantor_price_counts.sort_values(['sale_grantor', 'count'], ascending=[True, False])
    
    # Display the counts
    for grantor in grantor_price_counts['sale_grantor'].unique():
        print(f"\nGrantor: {grantor}")
        grantor_data = grantor_price_counts[grantor_price_counts['sale_grantor'] == grantor]
        for _, row in grantor_data.iterrows():
            print(f"  Sale price: ${row['sale_price']:,.2f} - Count: {row['count']}")
else:
    print("No sales with both 'CITY' and 'MAYOR' in grantor name found")
# Out:
# === Sales with 'CITY' and 'MAYOR' in Grantor Name ===
# No sales with both 'CITY' and 'MAYOR' in grantor name found

# %%
# Find sales with both "HOUSING" and "AUTH" in the grantor name
sales_df = sales_univ_pair["sales"]
housing_authority_sales = sales_df[
    sales_df['sale_grantor'].str.contains('HOUSING', na=False, case=False) & 
    sales_df['sale_grantor'].str.contains('AUTH', na=False, case=False)
]

print("\n=== Sales with 'HOUSING' and 'AUTH' in Grantor Name ===")
if len(housing_authority_sales) > 0:
    print(f"Found {len(housing_authority_sales)} sales with both 'HOUSING' and 'AUTH' in grantor name:")
    
    # Display sample of these sales
    print("\nSample of sales with 'HOUSING' and 'AUTH' in grantor name:")
    print(housing_authority_sales[['key', 'sale_grantor', 'sale_price', 'sale_date', 'convey_type']].head(10))
    
    # Group by grantor name and sale price, then count occurrences
    print("\nCounts of each sale price by grantor name containing 'HOUSING' and 'AUTH':")
    grantor_price_counts = housing_authority_sales.groupby(['sale_grantor', 'sale_price']).size().reset_index(name='count')
    
    # Sort by grantor name and then by count (descending)
    grantor_price_counts = grantor_price_counts.sort_values(['sale_grantor', 'count'], ascending=[True, False])
    
    # Display the counts
    for grantor in grantor_price_counts['sale_grantor'].unique():
        print(f"\nGrantor: {grantor}")
        grantor_data = grantor_price_counts[grantor_price_counts['sale_grantor'] == grantor]
        for _, row in grantor_data.iterrows():
            print(f"  Sale price: ${row['sale_price']:,.2f} - Count: {row['count']}")
else:
    print("No sales with both 'HOUSING' and 'AUTH' in grantor name found")
# Out:
# === Sales with 'HOUSING' and 'AUTH' in Grantor Name ===
# No sales with both 'HOUSING' and 'AUTH' in grantor name found

# %%
# Out:
# === Top 10 Properties by Building Area ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Print head of top ten assr_bldg_area_finished_sqft
#       2 print("\n=== Top 10 Properties by Building Area ===")
# ----> 3 if 'assr_bldg_area_finished_sqft' in universe_df.columns:
#       4     # Sort by building area in descending order and get top 10
#       5     top_area_properties = universe_df.sort_values(by='assr_bldg_area_finished_sqft', ascending=False).head(10)
#       7     # Select relevant columns to display
#
# NameError: name 'universe_df' is not defined
