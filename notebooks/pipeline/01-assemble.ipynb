# %% [markdown]
# # Assemble
#
# This notebook loads and assembles all your basic data sources, including tabulor and geospatial data.
#
# The final output is two dataframes:
#
# - UNIVERSE
# - SALES
#
# The SALES dataframe represents transactions or parcels; these are ownership transfers with prices, dates, and metadata.
# The UNIVERSE dataframe represents the parcels themselves (land and buildings, and their associated characteristics).
#
# These will be packaged together in a handy data structure called a `SalesUniversePair`, or `sup` for short. `openavmkit` provides many handy functions that carefully perform operations on `sup`s without mixing up their fields.
#
# The key thing to understand is that the **Assemble** notebook outputs a `sup` that represents *factual assertions* about the world. In later notebooks, we will have to add assumptions, opinions, and educated guesses, but we first will establish the firmest facts we can in this notebook.
#
# You can think of the two dataframes in the `sup` as answering the following questions:
#
# - UNIVERSE:
#   - Where is each parcel located in space, and what is its shape?
#   - What are the *current* characteristics of each parcel?
#     - Which parcels have buildings and which are vacant lots?
#     - How big is each parcel?
#     - What is the age/size/quality/condition/etc of each building?
# - SALES:
#   - Which parcels have sold?
#   - What prices did they sell for?
#   - What dates did they sell on?
#   - Which sales were valid?
#   - What characteristics were different *at the time of sale* from how the parcel is now?

# %%
# Change these as desired

# The slug of the locality you are currently working on
locality = "us-md-baltimorecity"

# Whether to print out a lot of stuff (can help with debugging) or stay mostly quiet
verbose = True

# Clear previous state for this notebook and start fresh
clear_checkpoints = False

# %% [markdown]
# # 1. Basic setup

# %%
import init_notebooks
init_notebooks.setup_environment()
# Out:
# Environment setup completed.

# %%
# import OpenAVMkit:
from openavmkit.pipeline import ( 
    init_notebook,
    from_checkpoint,
    delete_checkpoints,
    examine_df,
    examine_df_in_ridiculous_detail,
    examine_sup,
    examine_sup_in_ridiculous_detail,
    cloud_sync,
    load_settings,
    load_dataframes,
    process_data,
    process_sales,
    enrich_sup_streets,
    tag_model_groups_sup,
    write_notebook_output_sup
)

# %%
init_notebook(locality)
# Out:
# locality = us-md-baltimorecity
# base path = L:\git\openavmkit\notebooks\pipeline
# current path = L:\git\openavmkit\notebooks\pipeline\data\us-md-baltimorecity

# %%
if clear_checkpoints:
    delete_checkpoints("1-assemble")

# %%
settings = load_settings()

# %% [markdown]
# # 2. Sync with Cloud
# - If you have configured cloud storage, syncs with your remote storage
# - Reconciles your local input files with the versions on the remote server
# - Pulls down whatever is newer from the remote server
# - Uploads whatever is newer from your local machine

# %%
#cloud_sync(locality, verbose=True, env_path="../../../.env", settings=settings)

# %% [markdown]
# # 3. Load & process data

# %%
# load all of our initial dataframes, but don't do anything with them just yet
dataframes = from_checkpoint("1-assemble-01-load_dataframes", load_dataframes,
    {
        "settings":load_settings(),
        "verbose":verbose
    }
)

# %%
# assemble our data
sales_univ_pair = from_checkpoint("1-assemble-02-process_data", process_data,
    {
        "dataframes":dataframes, 
        "settings":settings, 
        "verbose":verbose
    }
)

# %%
df = sales_univ_pair.universe
print("▶️ INPUT df_in CRS:", df.crs)
print("▶️ INPUT df_in bounds:", df.geometry.total_bounds)
# Out:
# ▶️ INPUT df_in CRS: {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}, {"name": "World Geodetic System 1984 (G2296)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# ▶️ INPUT df_in bounds: [-76.711309   39.1972805 -76.5296665  39.372015 ]

# %%
# calculate street frontages
sales_univ_pair = from_checkpoint("1-assemble-03-enrich_streets", enrich_sup_streets,
    {
        "sup": sales_univ_pair,
        "settings":settings, 
        "verbose":verbose
    }
)
# Out:
# ▶️ INPUT df_in CRS: {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}, {"name": "World Geodetic System 1984 (G2296)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# ▶️ INPUT df_in bounds: [-76.711309   39.1972805 -76.5296665  39.372015 ]
# UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
# ▶ df after to_crs: +proj=utm +zone=18 +datum=WGS84 +units=m +type=crs
#   df.bounds (m): [ 352406.58385038 4339813.28087385  368236.29548508 4359449.84113314]
# T setup = 3s
# T prepare = 0s
# Loading network within (39.195269305450395,-76.7171119681943) -> (39.37649723361619,-76.52388897055145)
# T load street = 64s
# T edges = 7s
# Generating rays for 152991 edges with 8 jobs...
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.17461048648676988s.) Setting batch_size=2.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.029026508331298828s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  75 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.050551652908325195s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Done 127 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.056055545806884766s.) Setting batch_size=16.
# [Parallel(n_jobs=8)]: Done 216 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 408 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 648 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 920 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 1192 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 1496 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 1800 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 2136 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 2472 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 2840 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 3208 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 3608 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 4008 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 4440 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=8)]: Done 4872 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=8)]: Done 5336 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=8)]: Done 5800 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 6296 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=8)]: Done 6792 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=8)]: Done 7320 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=8)]: Done 7848 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 8408 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 8968 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=8)]: Done 9560 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=8)]: Done 10152 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=8)]: Done 10776 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=8)]: Done 11400 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=8)]: Done 12056 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=8)]: Done 12712 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=8)]: Done 13400 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=8)]: Done 14088 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=8)]: Done 14808 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=8)]: Done 15528 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=8)]: Done 16280 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=8)]: Done 17032 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=8)]: Done 17816 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=8)]: Done 18600 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=8)]: Done 19416 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=8)]: Done 20232 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=8)]: Done 21080 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=8)]: Done 21928 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=8)]: Done 22808 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=8)]: Done 23688 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=8)]: Done 24600 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=8)]: Done 25512 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=8)]: Done 26456 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=8)]: Done 27400 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19778945633041273s.) Setting batch_size=32.
# [Parallel(n_jobs=8)]: Done 28376 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=8)]: Done 30024 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=8)]: Done 32040 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=8)]: Done 34056 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=8)]: Batch computation too slow (2.000853353569476s.) Setting batch_size=6.
# [Parallel(n_jobs=8)]: Done 36084 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19410722403859382s.) Setting batch_size=12.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.1471388339996338s.) Setting batch_size=24.
# [Parallel(n_jobs=8)]: Done 36920 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=8)]: Done 38528 tasks      | elapsed:   55.1s
# [Parallel(n_jobs=8)]: Done 40136 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=8)]: Done 41792 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=8)]: Done 43448 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=8)]: Done 45152 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=8)]: Batch computation too slow (2.0132498046717466s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Done 46856 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Batch computation too fast (0.1974850525543213s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.050165414810180664s.) Setting batch_size=16.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.13492250442504883s.) Setting batch_size=32.
# [Parallel(n_jobs=8)]: Done 47752 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 50088 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 52488 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 54888 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 57352 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 59816 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Batch computation too slow (2.122033702380867s.) Setting batch_size=6.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19826028313898958s.) Setting batch_size=12.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.1411428451538086s.) Setting batch_size=24.
# [Parallel(n_jobs=8)]: Done 61290 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 63000 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 64944 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 66888 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 68880 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 70872 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 72912 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 74952 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 77040 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Batch computation too slow (2.012198201289989s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19977035423278813s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Done 78808 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Batch computation too fast (0.06606841087341309s.) Setting batch_size=16.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.12030839920043945s.) Setting batch_size=32.
# [Parallel(n_jobs=8)]: Done 80792 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 83640 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 86552 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 89464 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 92440 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 95416 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 98456 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 101496 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 104600 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Batch computation too slow (2.646263756194918s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Done 107592 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=8)]: Batch computation too fast (0.1846199506290965s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.11757445335388184s.) Setting batch_size=16.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19281935691833496s.) Setting batch_size=32.
# [Parallel(n_jobs=8)]: Done 109112 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=8)]: Done 112280 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=8)]: Done 115512 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 118744 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 122040 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 125336 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 128696 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 132056 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 135480 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 138904 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=8)]: Done 142392 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19811623065108774s.) Setting batch_size=64.
# [Parallel(n_jobs=8)]: Batch computation too slow (4.529350757598877s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.18930545042370206s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Done 145828 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=8)]: Batch computation too fast (0.08440876007080078s.) Setting batch_size=16.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.06906771659851074s.) Setting batch_size=32.
# [Parallel(n_jobs=8)]: Batch computation too fast (0.13793730735778809s.) Setting batch_size=64.
# [Parallel(n_jobs=8)]: Done 149976 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=8)]: Done 152991 out of 152991 | elapsed:  3.0min finished
# ▶ rays_gdf: +proj=utm +zone=18 +datum=WGS84 +units=m +type=crs
#   rays.bounds (m): [ 351741.04143925 4339536.03091597  368759.12648424 4359970.92087713]
# RAYS GDF
#           road_idx                     road_name road_type  \
# 0                0  Baltimore-Washington Parkway  motorway
# 1                0  Baltimore-Washington Parkway  motorway
# 2                0  Baltimore-Washington Parkway  motorway
# 3                0  Baltimore-Washington Parkway  motorway
# 4                0  Baltimore-Washington Parkway  motorway
# ...            ...                           ...       ...
# 20990433    152990                    1381993393   service
# 20990434    152990                    1381993393   service
# 20990435    152990                    1381993393   service
# 20990436    152990                    1381993393   service
# 20990437    152990                    1381993393   service
#
#                                                    geometry     angle
# 0         LINESTRING (354127.513 4340888.256, 354108.233...  2.451510
# 1         LINESTRING (354127.513 4340888.256, 354146.792... -0.690083
# 2         LINESTRING (354128.144 4340889.02, 354108.864 ...  2.451510
# 3         LINESTRING (354128.144 4340889.02, 354147.423 ... -0.690083
# 4         LINESTRING (354128.774 4340889.784, 354109.495...  2.451510
# ...                                                     ...       ...
# 20990433  LINESTRING (367063.928 4349834.974, 367038.964... -3.088254
# 20990434  LINESTRING (367063.974 4349834.116, 367088.939...  0.053339
# 20990435  LINESTRING (367063.974 4349834.116, 367039.01 ... -3.088254
# 20990436  LINESTRING (367064.02 4349833.259, 367088.984 ...  0.053339
# 20990437  LINESTRING (367064.02 4349833.259, 367039.056 ... -3.088254
#
# [20990438 rows x 5 columns]
# --> T rays_parallel = 230s
# ▶ parcels gdf: +proj=utm +zone=18 +datum=WGS84 +units=m +type=crs
#   parcels.bounds (m): [ 352406.58385038 4339813.28087385  368236.29548508 4359449.84113314]
# GDF
#             key                                        parcel_geom
# 0       0001001  POLYGON ((357648.544 4352400.592, 357647.7 435...
# 1       0001002  POLYGON ((357651.971 4352425.288, 357651.945 4...
# 2       0001003  POLYGON ((357652.789 4352401.625, 357652.815 4...
# 3       0001004  POLYGON ((357656.216 4352426.32, 357657.173 43...
# 4       0001005  POLYGON ((357660.617 4352426.462, 357661.53 43...
# ...         ...                                                ...
# 236500  PSC0020  POLYGON ((358018.025 4356182.746, 358009.276 4...
# 236501  PSC0065  POLYGON ((366866.257 4347429.908, 366866.226 4...
# 236502  PSC0070  POLYGON ((365158.935 4351297.208, 365154.751 4...
# 236503  PSC0075  POLYGON ((354993.102 4347941.94, 355018.028 43...
# 236504  PSC0085  POLYGON ((365381.65 4348129.685, 365376.916 43...
#
# [236505 rows x 2 columns]
# RAY PAR
#           road_idx   road_name road_type  \
# 15335           14   549573117  motorway
# 15337           14   549573117  motorway
# 15339           14   549573117  motorway
# 15341           14   549573117  motorway
# 15343           14   549573117  motorway
# ...            ...         ...       ...
# 20990420    152990  1381993393   service
# 20990421    152990  1381993393   service
# 20990421    152990  1381993393   service
# 20990422    152990  1381993393   service
# 20990422    152990  1381993393   service
#
#                                                    geometry     angle  \
# 15335     LINESTRING (360200.583 4347676.569, 360200.764... -1.563547
# 15337     LINESTRING (360201.574 4347676.576, 360201.756... -1.563547
# 15339     LINESTRING (360202.566 4347676.584, 360202.747... -1.563547
# 15341     LINESTRING (360203.558 4347676.591, 360203.739... -1.563547
# 15343     LINESTRING (360204.549 4347676.598, 360204.73 ... -1.563547
# ...                                                     ...       ...
# 20990420  LINESTRING (367063.62 4349840.514, 367088.579 ...  0.057560
# 20990421  LINESTRING (367063.62 4349840.514, 367038.661 ... -3.084033
# 20990421  LINESTRING (367063.62 4349840.514, 367038.661 ... -3.084033
# 20990422  LINESTRING (367063.677 4349839.525, 367088.636...  0.057560
# 20990422  LINESTRING (367063.677 4349839.525, 367088.636...  0.057560
#
#           index_right       key
# 15335           35017  1040002A
# 15337           35017  1040002A
# 15339           35017  1040002A
# 15341           35017  1040002A
# 15343           35017  1040002A
# ...               ...       ...
# 20990420       207454   6344004
# 20990421       207451   6344001
# 20990421       207452   6344002
# 20990422       207453   6344003
# 20990422       207454   6344004
#
# [62617506 rows x 7 columns]
# T block = 292s
# T ray_par = 8s
# T dist_0 = 0s
# T origins setup = 8s

# %% [markdown]
# # 4. Inspect results
#
# ## 4.1 Examine
#
# - Run the next cell and look at the printed out results.
# - Note the "Non-zero" and "Non-null" columns in particular and make sure they're what you expect
# - This view is for a quick glance to get a good idea of what all your data is

# %%
settings = load_settings()
examine_sup(sales_univ_pair, settings)

# %% [markdown]
# ## 4.2 Examine in ridiculous detail
#
# - You've looked, now LOOK AGAIN. This cell will run `describe()` for each numeric field and `value_counts()` for each categorical field.
# - Use this info to decide which variables are useful/useless
# - Consult this readout when you build your modeling group filters

# %%
examine_sup_in_ridiculous_detail(sales_univ_pair, settings)

# %% [markdown]
# ## 4.3 Look at it on a map
#
# - Go to your `out/look/` folder
# - There should be parquets there
# - Drop them into ArcGIS, QGIS, or Felt
# - Look at your location fields and make sure they make sense

# %% [markdown]
# # 5. Tag modeling groups
# - Separates rows into groups like "single family", "townhomes" and "commercial" as specified by the user
# - These groups will guide all further processing

# %%
settings = load_settings()
sales_univ_pair = from_checkpoint("1-assemble-04-tag_modeling_groups", tag_model_groups_sup,
    {
        "sup": sales_univ_pair, 
        "settings": settings, 
        "verbose": verbose
    }
)

# %% [markdown]
# # 6. Write out results

# %%
write_notebook_output_sup(sales_univ_pair, "1-assemble")

# %% [markdown]
# # 7. Look at it on a map!
# - Take the files output in the previous step and put them in a map viewer like QGIS, ArcGIS, or Felt
# - Look at them with your eyeballs
# - Make sure the data looks correct
# - If not, go back and fix it!
# - Don't proceed to the next step until everything looks right
